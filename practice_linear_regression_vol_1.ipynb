# %%
import pandas as pd
df1 = pd.read_csv('bensin.csv')
df1
# Out:
#     Liter  Kilometer
# 0      20      142.0
# 1      25      177.0
# 2      20      144.0
# 3      30      203.0
# 4      40      273.0
# ..    ...        ...
# 60     31      203.0
# 61     37      241.0
# 62     23      142.0
# 63     36      241.0
# 64     23      142.0
#
# [65 rows x 2 columns]

# %%
df1.describe()
# Out:
#            Liter   Kilometer
# count  65.000000   65.000000
# mean   26.446154  181.064615
# std     7.424686   49.741763
# min     6.000000   32.000000
# 25%    23.000000  144.000000
# 50%    25.000000  177.000000
# 75%    30.000000  212.000000
# max    45.000000  278.000000

# %%
import numpy as np
import sklearn.model_selection as ms
liter = df1[['Liter']]
kilometer = df1[['Kilometer']]
X_train, X_test, y_train, y_test = ms.train_test_split(liter, kilometer, test_size=0.2, random_state=0)
print(X_train.size, X_test.size)
# Out:
# 52 13

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.3-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.58.5-cp313-cp313-win_amd64.whl.metadata (109 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\ideapad s340\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ideapad s340\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\ideapad s340\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ideapad s340\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ideapad s340\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ideapad s340\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.3-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 3.8 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/8.1 MB 3.2 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/8.1 MB 2.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.1 MB 2.9 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.1 MB 3.0 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.1 MB 3.1 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 3.5 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 3.5 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp313-cp313-win_amd64.whl (223 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.5-cp313-cp313-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ----------------------- ---------------- 1.3/2.2 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 5.0 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp313-cp313-win_amd64.whl (71 kB)
# Installing collected packages: kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.58.5 kiwisolver-1.4.8 matplotlib-3.10.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import sklearn.model_selection as ms
import pandas as pd
import matplotlib.pyplot as plt
liter = df1[['Liter']]
kilometer = df1[['Kilometer']]
X_train, X_test, y_train, y_test = ms.train_test_split(liter, kilometer, test_size=0.2, random_state=0)
plt.scatter(X_train, y_train, edgecolors='r')
plt.xlabel('Liter')
plt.ylabel('Kilometer')
plt.title('konsumsi bahan bakar')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import numpy as np
import sklearn.model_selection as ms
import pandas as pd
import matplotlib.pyplot as plt
liter = df1[['Liter']]
kilometer = df1[['Kilometer']]
X_train, X_test, y_train, y_test = ms.train_test_split(liter, kilometer, test_size=0.2, random_state=0)
plt.scatter(X_train, y_train, edgecolors='r')
plt.xlabel('Liter')
plt.ylabel('Kilometer')
plt.title('konsumsi bahan bakar')
x1 = np.linspace(0,45)
y1 = 4 + 7 * x1
plt.plot(x1, y1)
plt.show()

# %%
import sklearn.linear_model as lm
model1 = lm.LinearRegression()
model1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model1.coef_
# Out:
# array([[6.45829591]])

# %%
model1.intercept_
# Out:
# array([10.64122249])

# %%
import pandas as pd
import numpy as np
import sklearn.model_selection as ms
import matplotlib.pyplot as plt
# Baca data
df1 = pd.read_csv('bensin.csv')
liter=df1[['Liter']]
kilometer = df1[['Kilometer']]
# Split data
X_train, X_test, y_train, y_test = ms.train_test_split(liter, kilometer, test_size=0.2, random_state=0)
plt.scatter(X_train, y_train, edgecolors='r')
plt.xlabel('Liter')
plt.ylabel('Kilometer')
plt.title('Konsumsi Bahan Bakar')
# Garis regresi manual (berdasarkan model sebelumnya)
xl = np.linspace(0, 45)
yl = 10.641 + 6.458 * xl
plt.plot(xl, yl)
plt.show()

# %%
import pandas as pd
import numpy as np
import sklearn.model_selection as ms
import matplotlib.pyplot as plt
# Baca data
df1 = pd.read_csv('bensin.csv')
liter=df1[['Liter']]
kilometer = df1[['Kilometer']]
# Split data
X_train, X_test, y_train, y_test = ms.train_test_split(liter, kilometer, test_size=0.2, random_state=0)

# Garis regresi manual (berdasarkan model sebelumnya)
xl = np.linspace(0, 45)
yl = 10.641 + 6.458 * xl

#buat grafik
plt.figure(figsize=(8, 6))
plt.scatter(X_train, y_train, edgecolors='r', label='Data Asli')
plt.plot(xl, yl, color='blue', label='Garis Regresi')

#tambah visual
plt.xlabel('Liter')
plt.ylabel('Kilometer')
plt.title('Konsumsi Bahan Bakar')
plt.legend()
plt.grid(True)

plt.show()

# %%
r2 = model1.score(X_test, y_test)
print(r2)
# Out:
# 0.9798523775622333

# %%
import sklearn.linear_model as lm
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Buat dan latih model
model1 = lm.LinearRegression()
model1.fit(X_train, y_train)

# Hitung skor R^2
r2 = model1.score(X_test, y_test)
print("R² Score:", round(r2, 2))

# Prediksi di data test
y_pred = model1.predict(X_test)

# Hitung MAE dan MSE
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print("Mean Absolute Error (MAE):", round(mae, 2))
print("Mean Squared Error (MSE):", round(mse, 2))
# Out:
# R² Score: 0.98
# Mean Absolute Error (MAE): 6.98
# Mean Squared Error (MSE): 63.86

# %%
jarak = model1.predict([[60]])
print(jarak)
# Out:
# [[398.13897723]]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
prediksi = model1.predict(X_test)
print(prediksi)
# Out:
# [[107.51566118]
#  [172.0986203 ]
#  [172.0986203 ]
#  [159.18202848]
#  [139.80714074]
#  [268.97305898]
#  [204.39009986]
#  [236.68157942]
#  [ 75.22418162]
#  [243.13987534]
#  [172.0986203 ]
#  [139.80714074]
#  [191.47350804]]

# %%
print(y_test)
kilometer
# Out:
#     Kilometer
# 45      102.0
# 29      167.0
# 43      177.0
# 62      142.0
# 34      144.0
# 33      278.0
# 31      211.0
# 40      241.0
# 26       65.0
# 63      241.0
# 22      166.2
# 2       144.0
# 11      180.0
#     Kilometer
# 0       142.0
# 1       177.0
# 2       144.0
# 3       203.0
# 4       273.0
# ..        ...
# 60      203.0
# 61      241.0
# 62      142.0
# 63      241.0
# 64      142.0
#
# [65 rows x 1 columns]

# %%
import pickle

# Simpan model ke file
with open('model.pkl', 'wb') as file:
    pickle.dump(model1, file)

print("Model berhasil disimpan!")
# Out:
# Model berhasil disimpan!
